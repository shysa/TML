# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
sns.set(style="ticks")

# %%
data = pd.read_csv('../data/flats_moscow.csv', sep=",")

# %%
# Список колонок с типами данных
data.dtypes
# Out:
# Unnamed: 0      int64
# price           int64
# totsp           int64
# livesp          int64
# kitsp         float64
# dist          float64
# metrdist        int64
# walk            int64
# brick           int64
# floor           int64
# code            int64
# dtype: object

# %%
data.head()
# Out:
#    Unnamed: 0  price  totsp  livesp  kitsp  dist  metrdist  walk  brick  \
# 0           1     81     58      40    6.0  12.5         7     1      1
# 1           2     75     44      28    6.0  13.5         7     1      0
# 2           3    128     70      42    6.0  14.5         3     1      1
# 3           4     95     61      37    6.0  13.5         7     1      0
# 4           5    330    104      60   11.0  10.5         7     0      1
#
#    floor  code
# 0      1     3
# 1      1     6
# 2      1     3
# 3      1     1
# 4      1     3

# %%
# Проверка на пропуски
data.isnull().sum()
# Out:
# Unnamed: 0    0
# price         0
# totsp         0
# livesp        0
# kitsp         0
# dist          0
# metrdist      0
# walk          0
# brick         0
# floor         0
# code          0
# dtype: int64

# %%
# Размер набора данных: (строки, колонки)
data.shape
# Out:
# (2040, 11)

# %%
total_count = data.shape[0]
print('Всего строк: {}'.format(total_count))
# Out:
# Всего строк: 2040

# %%
# Основные статистические характеристики набора данных
data.describe()
# Out:
#         Unnamed: 0        price        totsp       livesp        kitsp  \
# count  2040.000000  2040.000000  2040.000000  2040.000000  2040.000000
# mean   1020.500000   127.496569    73.084314    46.337255     8.898529
# std     589.041594    51.878220    15.123450     7.894348     2.787073
# min       1.000000    50.000000    44.000000    28.000000     5.000000
# 25%     510.750000    95.000000    62.000000    42.000000     7.000000
# 50%    1020.500000   115.000000    73.500000    45.000000     9.000000
# 75%    1530.250000   142.000000    79.000000    50.000000    10.000000
# max    2040.000000   730.000000   192.000000   102.000000    25.000000
#
#               dist     metrdist         walk        brick        floor  \
# count  2040.000000  2040.000000  2040.000000  2040.000000  2040.000000
# mean     11.015686     8.117157     0.685784     0.323039     0.790686
# std       3.375539     3.815574     0.464317     0.467752     0.406918
# ...

# %%
data['code'].unique()
# Out:
# array([3, 6, 1, 8, 4, 5, 7, 2], dtype=int64)

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(ax=ax, x='livesp', y='price', data=data)

# %%
fighue, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(ax=ax, x='livesp', y='price', data=data, hue='dist')

# %%
figdist, ax = plt.subplots(figsize=(10,10))
sns.distplot(data['price'])

# %%
sns.jointplot(x='livesp', y='price', data=data)

# %%
sns.jointplot(x='livesp', y='price', data=data, kind="kde")

# %%
data.corr(method='pearson')
# Out:
#             Unnamed: 0     price     totsp    livesp     kitsp      dist  \
# Unnamed: 0    1.000000 -0.022761 -0.036063 -0.031432 -0.029838  0.029367
# price        -0.022761  1.000000  0.756042  0.729614  0.597235 -0.331563
# totsp        -0.036063  0.756042  1.000000  0.862236  0.781536 -0.114698
# livesp       -0.031432  0.729614  0.862236  1.000000  0.573528 -0.197228
# kitsp        -0.029838  0.597235  0.781536  0.573528  1.000000 -0.061874
# dist          0.029367 -0.331563 -0.114698 -0.197228 -0.061874  1.000000
# metrdist      0.007293 -0.152116 -0.041426 -0.052112 -0.028490  0.099185
# walk         -0.010263  0.151996  0.011876  0.060367 -0.009112 -0.175277
# brick        -0.034944  0.260835  0.121287  0.254309 -0.019235 -0.394742
# floor         0.016642  0.132564  0.113723  0.094658  0.117050  0.020530
# code         -0.020986 -0.089623 -0.021959 -0.005480 -0.054632 -0.191975
#
#             metrdist      walk     brick     floor      code
# ...

# %%
data.corr(method='kendall')
# Out:
#             Unnamed: 0     price     totsp    livesp     kitsp      dist  \
# Unnamed: 0    1.000000 -0.016284 -0.028642 -0.027992 -0.019367  0.023070
# price        -0.016284  1.000000  0.590742  0.506202  0.494208 -0.255946
# totsp        -0.028642  0.590742  1.000000  0.658063  0.649599 -0.079131
# livesp       -0.027992  0.506202  0.658063  1.000000  0.405436 -0.142573
# kitsp        -0.019367  0.494208  0.649599  0.405436  1.000000 -0.019973
# dist          0.023070 -0.255946 -0.079131 -0.142573 -0.019973  1.000000
# metrdist      0.005220 -0.111954 -0.008968 -0.019362 -0.001230  0.081346
# walk         -0.008382  0.144860  0.003467  0.046134 -0.026902 -0.155314
# brick        -0.028539  0.224930  0.082351  0.200027 -0.055019 -0.339736
# floor         0.013592  0.129073  0.100711  0.075247  0.104325  0.025458
# code         -0.014651 -0.062721 -0.001891  0.006572 -0.030473 -0.184100
#
#             metrdist      walk     brick     floor      code
# ...

# %%
data.corr(method='spearman')
# Out:
#             Unnamed: 0     price     totsp    livesp     kitsp      dist  \
# Unnamed: 0    1.000000 -0.024281 -0.042338 -0.041216 -0.027364  0.033723
# price        -0.024281  1.000000  0.768785  0.671953  0.651975 -0.366695
# totsp        -0.042338  0.768785  1.000000  0.819544  0.801094 -0.114953
# livesp       -0.041216  0.671953  0.819544  1.000000  0.542124 -0.199267
# kitsp        -0.027364  0.651975  0.801094  0.542124  1.000000 -0.028054
# dist          0.033723 -0.366695 -0.114953 -0.199267 -0.028054  1.000000
# metrdist      0.007006 -0.153349 -0.012387 -0.026200 -0.001287  0.108896
# walk         -0.010263  0.176057  0.004185  0.054960 -0.030900 -0.184136
# brick        -0.034944  0.273369  0.099418  0.238296 -0.063193 -0.402783
# floor         0.016642  0.156869  0.121583  0.089643  0.119827  0.030183
# code         -0.020483 -0.086993 -0.002355  0.010491 -0.040110 -0.253626
#
#             metrdist      walk     brick     floor      code
# ...

# %%
figwarmmaps, ax = plt.subplots(1, 3, sharex='col', sharey='row', figsize=(15,5))
sns.heatmap(data.corr(method='pearson'), ax=ax[0], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='kendall'), ax=ax[1], annot=True, fmt='.2f')
sns.heatmap(data.corr(method='spearman'), ax=ax[2], annot=True, fmt='.2f')
fig.suptitle('Корреляционные матрицы, построенные различными методами')
ax[0].title.set_text('Pearson')
ax[1].title.set_text('Kendall')
ax[2].title.set_text('Spearman')
